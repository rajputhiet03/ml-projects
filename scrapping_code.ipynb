# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import os
import urllib
import urllib.request

driver=webdriver.Chrome("C:/Users/HP/Desktop/images/chromedriver_win32/chromedriver.exe")
driver.get('https://www.amazon.in/s?k=jeans+for+men&ref=nb_sb_noss_2')

# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=1000):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(1000,2000)
    
    name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/81m75ojT-1L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91mXH+SEo7L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71GR2YAt-7L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91pjP5bPiEL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/812iG5h2AQL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61Don-d8JfL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81MSkO5TK9L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Nx4XaxG6L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/613aUOVUTyL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81beYvllyZL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/714EXTMcpuL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81ZVm7gJ8PL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81LBrUpngfL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/813z6di-TUL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81EhCxcqeiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81GI8zYVFOL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91YbZqWjO0L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61ZGXTSfA3L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81lPknmdTGL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81btTA9HKPL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71ZtjyHxeML._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71pHBgvYSPL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/616wvPvhipL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81cOT4IQ2jL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71LO55xRq3L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81VseK3SqeL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81q6SbxfMuL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81FzGcAuj7L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/618r4PBS73L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/718jYQdzlOL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91BZB51YS6L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61TwfPRLhrL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61xg9CpjNjL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81fwKepgI6L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81CBxi1sSpL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/617SAeg8hPL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71j77-mix-L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71QX+MwnvhL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81EUToudE8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71hzd4S7uyL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Dd1EIUYaL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/41ipyFTyb-L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81ngbj+RvzL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91+YWYDf6AL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Ex8-hTBHL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71T6bPxPsNL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81tfWtSy8iL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71DHeA3R-oL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/8137yBEGsRL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/719Kj4n2mAL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71yrEovAM0L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71hPaI5YWaL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/611Uj4IofCL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/814f35i5j8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81rD0Tg5c3L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Op5HUd+1L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61WqFryqYuL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81iJrp5Jr8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61z7TKqwD2L._AC_UL320_.jpg
# loop break
