# %% [markdown]
# # PROJECT - 21

# %% [markdown]
# # CALIFORNIA DATASET

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings ("ignore")

# %% [markdown]
# # LOADING DATSET

# %%
data=pd.read_csv("california_housing.csv")
data
# Out:
#        longitude  latitude  housingage  totalrooms  totalbedrooms  population  \
# 0        -122.23     37.88          41         880          129.0         322
# 1        -122.22     37.86          21        7099         1106.0        2401
# 2        -122.24     37.85          52        1467          190.0         496
# 3        -122.25     37.85          52        1274          235.0         558
# 4        -122.25     37.85          52        1627          280.0         565
# 5        -122.25     37.85          52         919          213.0         413
# 6        -122.25     37.84          52        2535          489.0        1094
# 7        -122.25     37.84          52        3104          687.0        1157
# 8        -122.26     37.84          42        2555          665.0        1206
# 9        -122.25     37.84          52        3549          707.0        1551
# 10       -122.26     37.85          52        2202          434.0         910
# ...

# %%
data.head()
# Out:
#    longitude  latitude  housingage  totalrooms  totalbedrooms  population  \
# 0    -122.23     37.88          41         880          129.0         322
# 1    -122.22     37.86          21        7099         1106.0        2401
# 2    -122.24     37.85          52        1467          190.0         496
# 3    -122.25     37.85          52        1274          235.0         558
# 4    -122.25     37.85          52        1627          280.0         565
#
#    households  medianincome  housevalue
# 0         126        8.3252      452600
# 1        1138        8.3014      358500
# 2         177        7.2574      352100
# 3         219        5.6431      341300
# 4         259        3.8462      342200

# %%
data.tail()
# Out:
#        longitude  latitude  housingage  totalrooms  totalbedrooms  population  \
# 20635    -121.09     39.48          25        1665          374.0         845
# 20636    -121.21     39.49          18         697          150.0         356
# 20637    -121.22     39.43          17        2254          485.0        1007
# 20638    -121.32     39.43          18        1860          409.0         741
# 20639    -121.24     39.37          16        2785          616.0        1387
#
#        households  medianincome  housevalue
# 20635         330        1.5603       78100
# 20636         114        2.5568       77100
# 20637         433        1.7000       92300
# 20638         349        1.8672       84700
# 20639         530        2.3886       89400

# %%
data.describe()
# Out:
#           longitude      latitude    housingage    totalrooms  totalbedrooms  \
# count  20640.000000  20640.000000  20640.000000  20640.000000   20433.000000
# mean    -119.569704     35.631861     28.639486   2635.763081     537.870553
# std        2.003532      2.135952     12.585558   2181.615252     421.385070
# min     -124.350000     32.540000      1.000000      2.000000       1.000000
# 25%     -121.800000     33.930000     18.000000   1447.750000     296.000000
# 50%     -118.490000     34.260000     29.000000   2127.000000     435.000000
# 75%     -118.010000     37.710000     37.000000   3148.000000     647.000000
# max     -114.310000     41.950000     52.000000  39320.000000    6445.000000
#
#          population    households  medianincome     housevalue
# count  20640.000000  20640.000000  20640.000000   20640.000000
# mean    1425.476744    499.539680      3.870671  206855.816909
# std     1132.462122    382.329753      1.899822  115395.615874
# ...

# %%
data.dtypes
# Out:
# longitude        float64
# latitude         float64
# housingage         int64
# totalrooms         int64
# totalbedrooms    float64
# population         int64
# households         int64
# medianincome     float64
# housevalue         int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
# longitude        20640 non-null float64
# latitude         20640 non-null float64
# housingage       20640 non-null int64
# totalrooms       20640 non-null int64
# totalbedrooms    20433 non-null float64
# population       20640 non-null int64
# households       20640 non-null int64
# medianincome     20640 non-null float64
# housevalue       20640 non-null int64
# dtypes: float64(4), int64(5)
# memory usage: 1.4 MB

# %%
data.isnull().sum()
# Out:
# longitude          0
# latitude           0
# housingage         0
# totalrooms         0
# totalbedrooms    207
# population         0
# households         0
# medianincome       0
# housevalue         0
# dtype: int64

# %%
data.corr()
# Out:
#                longitude  latitude  housingage  totalrooms  totalbedrooms  \
# longitude       1.000000 -0.924664   -0.108197    0.044568       0.069608
# latitude       -0.924664  1.000000    0.011173   -0.036100      -0.066983
# housingage     -0.108197  0.011173    1.000000   -0.361262      -0.320451
# totalrooms      0.044568 -0.036100   -0.361262    1.000000       0.930380
# totalbedrooms   0.069608 -0.066983   -0.320451    0.930380       1.000000
# population      0.099773 -0.108785   -0.296244    0.857126       0.877747
# households      0.055310 -0.071035   -0.302916    0.918484       0.979728
# medianincome   -0.015176 -0.079809   -0.119034    0.198050      -0.007723
# housevalue     -0.045967 -0.144160    0.105623    0.134153       0.049686
#
#                population  households  medianincome  housevalue
# longitude        0.099773    0.055310     -0.015176   -0.045967
# latitude        -0.108785   -0.071035     -0.079809   -0.144160
# ...

# %% [markdown]
# # FILLING MISSING VALUES

# %%
data["totalbedrooms"].mean()
# Out:
# 537.8705525375618

# %%
data["totalbedrooms"]=data["totalbedrooms"].fillna(data["totalbedrooms"].mean())

# %%
data.isnull().sum()
# Out:
# longitude        0
# latitude         0
# housingage       0
# totalrooms       0
# totalbedrooms    0
# population       0
# households       0
# medianincome     0
# housevalue       0
# dtype: int64

# %% [markdown]
# # CHECKING OUTLIERS

# %%
data["longitude"].plot.box()

# %%
data["latitude"].plot.box()

# %%
data["housingage"].plot.box()

# %%
data["totalrooms"].plot.box()

# %%
data["totalbedrooms"].plot.box()

# %%
data["population"].plot.box()

# %%
data["households"].plot.box()

# %% [markdown]
# # IMPORT ZSCORE FOR REMOVING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(data))
z
# Out:
# array([[1.32783522, 1.05254828, 0.98214266, ..., 0.97703285, 2.34476576,
#         2.12963148],
#        [1.32284391, 1.04318455, 0.60701891, ..., 1.66996103, 2.33223796,
#         1.31415614],
#        [1.33282653, 1.03850269, 1.85618152, ..., 0.84363692, 1.7826994 ,
#         1.25869341],
#        ...,
#        [0.8237132 , 1.77823747, 0.92485123, ..., 0.17404163, 1.14259331,
#         0.99274649],
#        [0.87362627, 1.77823747, 0.84539315, ..., 0.39375258, 1.05458292,
#         1.05860847],
#        [0.83369581, 1.75014627, 1.00430931, ..., 0.07967221, 0.78012947,
#         1.01787803]])

# %%
thresholds=3
print(np.where(z>3))
# Out:
# (array([   95,    95,   104, ..., 20629, 20629, 20629], dtype=int64), array([4, 6, 4, ..., 4, 5, 6], dtype=int64))

# %%
data_new=data[(z<3).all(axis=1)]

# %%
data_new
# Out:
#        longitude  latitude  housingage  totalrooms  totalbedrooms  population  \
# 0        -122.23     37.88          41         880          129.0         322
# 1        -122.22     37.86          21        7099         1106.0        2401
# 2        -122.24     37.85          52        1467          190.0         496
# 3        -122.25     37.85          52        1274          235.0         558
# 4        -122.25     37.85          52        1627          280.0         565
# 5        -122.25     37.85          52         919          213.0         413
# 6        -122.25     37.84          52        2535          489.0        1094
# 7        -122.25     37.84          52        3104          687.0        1157
# 8        -122.26     37.84          42        2555          665.0        1206
# 9        -122.25     37.84          52        3549          707.0        1551
# 10       -122.26     37.85          52        2202          434.0         910
# ...

# %%
sns.heatmap(data_new.isnull())

# %%
data_new.corr()
# Out:
#                longitude  latitude  housingage  totalrooms  totalbedrooms  \
# longitude       1.000000 -0.924430   -0.098881    0.008103       0.044725
# latitude       -0.924430  1.000000    0.001062   -0.009188      -0.054944
# housingage     -0.098881  0.001062    1.000000   -0.348180      -0.285994
# totalrooms      0.008103 -0.009188   -0.348180    1.000000       0.895709
# totalbedrooms   0.044725 -0.054944   -0.285994    0.895709       1.000000
# population      0.104555 -0.127111   -0.262569    0.798371       0.836626
# households      0.034916 -0.066506   -0.264232    0.891620       0.967137
# medianincome   -0.015781 -0.082045   -0.140231    0.259033      -0.019537
# housevalue     -0.046107 -0.146238    0.117536    0.171421       0.075431
#
#                population  households  medianincome  housevalue
# longitude        0.104555    0.034916     -0.015781   -0.046107
# latitude        -0.127111   -0.066506     -0.082045   -0.146238
# ...

# %%
sns.heatmap(data_new.corr())

# %%
data_new.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000006463D30>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data_new)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C6AB748>,
# ...
#       dtype=object)

# %%
sns.pairplot(data_new)

# %% [markdown]
# # MIN MAX SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data_new=scaler.fit_transform(data_new.astype(float))
data_new
# Out:
# array([[0.21115538, 0.5674814 , 0.78431373, ..., 0.07551766, 0.86408207,
#         0.90226638],
#        [0.21215139, 0.565356  , 0.39215686, ..., 0.69183922, 0.86145403,
#         0.70824656],
#        [0.21015936, 0.5642933 , 1.        , ..., 0.10657734, 0.74617389,
#         0.69505074],
#        ...,
#        [0.31175299, 0.73219979, 0.31372549, ..., 0.26248477, 0.13251695,
#         0.15938285],
#        [0.30179283, 0.73219979, 0.33333333, ..., 0.21132765, 0.15097944,
#         0.14371281],
#        [0.30976096, 0.72582359, 0.29411765, ..., 0.32155907, 0.20855326,
#         0.15340349]])

# %%
df=pd.DataFrame(data_new)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.211155  0.567481  0.784314  0.095674  0.071388  0.066251  0.075518
# 1  0.212151  0.565356  0.392157  0.773346  0.620573  0.498027  0.691839
# 2  0.210159  0.564293  1.000000  0.159638  0.105677  0.102388  0.106577
# 3  0.209163  0.564293  1.000000  0.138607  0.130972  0.115265  0.132156
# 4  0.209163  0.564293  1.000000  0.177073  0.156268  0.116719  0.156516
#
#           7         8
# 0  0.864082  0.902266
# 1  0.861454  0.708247
# 2  0.746174  0.695051
# 3  0.567920  0.672783
# 4  0.369504  0.674638

# %% [markdown]
# # SPLITTING INTO X AND Y

# %%
x=df.drop(8,axis=1)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.211155  0.567481  0.784314  0.095674  0.071388  0.066251  0.075518
# 1  0.212151  0.565356  0.392157  0.773346  0.620573  0.498027  0.691839
# 2  0.210159  0.564293  1.000000  0.159638  0.105677  0.102388  0.106577
# 3  0.209163  0.564293  1.000000  0.138607  0.130972  0.115265  0.132156
# 4  0.209163  0.564293  1.000000  0.177073  0.156268  0.116719  0.156516
#
#           7
# 0  0.864082
# 1  0.861454
# 2  0.746174
# 3  0.567920
# 4  0.369504

# %%
y=df[8]
y
# Out:
# 0        0.902266
# 1        0.708247
# 2        0.695051
# 3        0.672783
# 4        0.674638
# 5        0.525155
# 6        0.585979
# 7        0.466804
# 8        0.436495
# 9        0.507423
# 10       0.549484
# 11       0.467629
# 12       0.409279
# 13       0.363506
# 14       0.297320
# 15       0.257733
# 16       0.283506
# 17       0.289692
# 18       0.296289
# 19       0.304949
# 20       0.273197
# 21       0.298558
# 22       0.203919
# 23       0.174641
# 24       0.242475
# 25       0.190723
# 26       0.162476
# 27       0.186599
# 28       0.193610
# 29       0.241238
#            ...
# 19716    0.087631
# 19717    0.062888
# 19718    0.065981
# 19719    0.068662
# 19720    0.079177
# 19721    0.088661
# 19722    0.087631
# 19723    0.082682
# 19724    0.115053
# 19725    0.099795
# 19726    0.173403
# 19727    0.175259
# 19728    0.128868
# 19729    0.107218
# 19730    0.104125
# 19731    0.148867
# 19732    0.117527
# 19733    0.162476
# 19734    0.304125
# ...

# %% [markdown]
# # TRAINING AND TESTING PHASE

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=0)

# %%
x_train.shape
# Out:
# (13229, 8)

# %%
x_test.shape
# Out:
# (6517, 8)

# %%
y_train.shape
# Out:
# (13229,)

# %%
y_test.shape
# Out:
# (6517,)

# %% [markdown]
# # APPLYING ALGORITHMS

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predlr=lr.predict(x_test)

# %%
print(lr.score(x_train,y_train))
# Out:
# 0.6216942648790902

# %%
print(r2_score(y_test,predlr))
# Out:
# 0.6386183709196924

# %%
print(mean_squared_error(y_test,predlr))
# Out:
# 0.018594269953962718

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
num_folds = 20
num_instances = len(x)
loocv=LeaveOneOut()
model=LinearRegression()
results=cross_val_score(model, x, y, cv=loocv)
print("Accuracy: %.3f%% (%.3f%%)" % (results.mean()*100.0, results.std()*100.0))
# Out:
# Accuracy: nan% (nan%)

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(lr,"CALIFORNIA.pkl")
# Out:
# ['CALIFORNIA.pkl']
